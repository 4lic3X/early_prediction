# %%
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # UCSD

# %%
import pandas as pd

ucsd_data = pd.read_csv("metrics/ucsd_metrics_finetune.csv")
ucsd_data.head()
# Out:
#    Precision  Recall   ROC_AUC    PR_AUC  Accuracy   F1     Model  Chapter  \
# 0        0.0     0.0  0.520692  0.439662  0.639339  0.0  Original        1
# 1        0.0     0.0  0.677140  0.645569  0.639339  0.0  Original        2
# 2        0.0     0.0  0.693060  0.649015  0.639339  0.0  Original        3
# 3        0.0     0.0  0.701642  0.661887  0.639339  0.0  Original        4
# 4        0.0     0.0  0.727092  0.658862  0.639339  0.0  Original        5
#
#    Trial
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
import utils

utils.plot_metrics_subplots(ucsd_data, limit_y=False)

# %% [markdown]
# # UCLA

# %%
ucla_data = pd.read_csv("metrics/ucla_metrics_finetune.csv")

# %%
utils.plot_metrics_subplots(ucla_data, limit_y=False)

# %% [markdown]
# # UCSD -> UCLA

# %%
transfer_data = pd.read_csv("metrics/transfer_metrics_finetune.csv")

# %%
utils.plot_metrics_subplots(transfer_data, limit_y=False)

# %%
utils.plot_metrics_subplots(
    transfer_data,
    limit_y=False,
    exclude_models=["Chapter Ensemble", "Sequence Original", "Sequence Augmented"],
)
